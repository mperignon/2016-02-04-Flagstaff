# %%
import requests
import json
import pandas as pd

token = 'RiQdQYKoEqYhQXPXuoNoonkzYPajlwIr'
headers = {'token': token}

url = 'http://www.ncdc.noaa.gov/cdo-web/api/v2/stations?'
url += 'datasetid=NORMAL_DLY'
url += '&extent=' + '35.10,-111.75,35.30,-111.5'
url += '&limit=100'

r = requests.get(url, headers=headers)
data_ = r.json()
stations = pd.io.json.json_normalize(data_['results'])

stations_list = list(stations['id'])

# %%
stations_list
# Out:
# [u'GHCND:USC00023009',
#  u'GHCND:USC00023160',
#  u'GHCND:USC00029156',
#  u'GHCND:USW00003103']

# %%
stationID = ''

for st in stations_list:
    stationID = stationID + '&stationid=' + st
    

startDate = '2010-01-01'
endDate = '2010-12-31'

url = 'http://www.ncdc.noaa.gov/cdo-web/api/v2/data?'
url += 'datasetid=NORMAL_DLY'
url += '&datatypeid=DLY-TAVG-NORMAL'
url += stationID
url += '&startdate=' + startDate
url += '&enddate=' + endDate
url += '&limit=1000'

r = requests.get(url, headers=headers)

data_ = r.json()
data = pd.io.json.json_normalize(data_['results'])

data['datetime']=pd.to_datetime(data['date'])

# %%
data
# Out:
#     attributes         datatype                 date            station  \
# 0            R  DLY-TAVG-NORMAL  2010-01-01T00:00:00  GHCND:USC00023009
# 1            S  DLY-TAVG-NORMAL  2010-01-01T00:00:00  GHCND:USC00023160
# 2            Q  DLY-TAVG-NORMAL  2010-01-01T00:00:00  GHCND:USC00029156
# 3            S  DLY-TAVG-NORMAL  2010-01-01T00:00:00  GHCND:USW00003103
# 4            R  DLY-TAVG-NORMAL  2010-01-02T00:00:00  GHCND:USC00023009
# 5            S  DLY-TAVG-NORMAL  2010-01-02T00:00:00  GHCND:USC00023160
# 6            Q  DLY-TAVG-NORMAL  2010-01-02T00:00:00  GHCND:USC00029156
# 7            S  DLY-TAVG-NORMAL  2010-01-02T00:00:00  GHCND:USW00003103
# 8            R  DLY-TAVG-NORMAL  2010-01-03T00:00:00  GHCND:USC00023009
# 9            S  DLY-TAVG-NORMAL  2010-01-03T00:00:00  GHCND:USC00023160
# 10           Q  DLY-TAVG-NORMAL  2010-01-03T00:00:00  GHCND:USC00029156
# 11           S  DLY-TAVG-NORMAL  2010-01-03T00:00:00  GHCND:USW00003103
# 12           R  DLY-TAVG-NORMAL  2010-01-04T00:00:00  GHCND:USC00023009
# 13           S  DLY-TAVG-NORMAL  2010-01-04T00:00:00  GHCND:USC00023160
# 14           Q  DLY-TAVG-NORMAL  2010-01-04T00:00:00  GHCND:USC00029156
# 15           S  DLY-TAVG-NORMAL  2010-01-04T00:00:00  GHCND:USW00003103
# 16           R  DLY-TAVG-NORMAL  2010-01-05T00:00:00  GHCND:USC00023009
# 17           S  DLY-TAVG-NORMAL  2010-01-05T00:00:00  GHCND:USC00023160
# 18           Q  DLY-TAVG-NORMAL  2010-01-05T00:00:00  GHCND:USC00029156
# 19           S  DLY-TAVG-NORMAL  2010-01-05T00:00:00  GHCND:USW00003103
# 20           R  DLY-TAVG-NORMAL  2010-01-06T00:00:00  GHCND:USC00023009
# 21           S  DLY-TAVG-NORMAL  2010-01-06T00:00:00  GHCND:USC00023160
# 22           Q  DLY-TAVG-NORMAL  2010-01-06T00:00:00  GHCND:USC00029156
# 23           S  DLY-TAVG-NORMAL  2010-01-06T00:00:00  GHCND:USW00003103
# 24           R  DLY-TAVG-NORMAL  2010-01-07T00:00:00  GHCND:USC00023009
# 25           S  DLY-TAVG-NORMAL  2010-01-07T00:00:00  GHCND:USC00023160
# 26           Q  DLY-TAVG-NORMAL  2010-01-07T00:00:00  GHCND:USC00029156
# 27           S  DLY-TAVG-NORMAL  2010-01-07T00:00:00  GHCND:USW00003103
# 28           R  DLY-TAVG-NORMAL  2010-01-08T00:00:00  GHCND:USC00023009
# 29           S  DLY-TAVG-NORMAL  2010-01-08T00:00:00  GHCND:USC00023160
# ..         ...              ...                  ...                ...
# 970          Q  DLY-TAVG-NORMAL  2010-08-31T00:00:00  GHCND:USC00029156
# 971          R  DLY-TAVG-NORMAL  2010-08-31T00:00:00  GHCND:USW00003103
# 972          R  DLY-TAVG-NORMAL  2010-09-01T00:00:00  GHCND:USC00023009
# 973          S  DLY-TAVG-NORMAL  2010-09-01T00:00:00  GHCND:USC00023160
# 974          Q  DLY-TAVG-NORMAL  2010-09-01T00:00:00  GHCND:USC00029156
# 975          R  DLY-TAVG-NORMAL  2010-09-01T00:00:00  GHCND:USW00003103
# 976          R  DLY-TAVG-NORMAL  2010-09-02T00:00:00  GHCND:USC00023009
# 977          S  DLY-TAVG-NORMAL  2010-09-02T00:00:00  GHCND:USC00023160
# 978          Q  DLY-TAVG-NORMAL  2010-09-02T00:00:00  GHCND:USC00029156
# 979          R  DLY-TAVG-NORMAL  2010-09-02T00:00:00  GHCND:USW00003103
# 980          R  DLY-TAVG-NORMAL  2010-09-03T00:00:00  GHCND:USC00023009
# 981          S  DLY-TAVG-NORMAL  2010-09-03T00:00:00  GHCND:USC00023160
# 982          Q  DLY-TAVG-NORMAL  2010-09-03T00:00:00  GHCND:USC00029156
# 983          R  DLY-TAVG-NORMAL  2010-09-03T00:00:00  GHCND:USW00003103
# 984          R  DLY-TAVG-NORMAL  2010-09-04T00:00:00  GHCND:USC00023009
# 985          S  DLY-TAVG-NORMAL  2010-09-04T00:00:00  GHCND:USC00023160
# 986          Q  DLY-TAVG-NORMAL  2010-09-04T00:00:00  GHCND:USC00029156
# 987          R  DLY-TAVG-NORMAL  2010-09-04T00:00:00  GHCND:USW00003103
# 988          R  DLY-TAVG-NORMAL  2010-09-05T00:00:00  GHCND:USC00023009
# 989          S  DLY-TAVG-NORMAL  2010-09-05T00:00:00  GHCND:USC00023160
# 990          Q  DLY-TAVG-NORMAL  2010-09-05T00:00:00  GHCND:USC00029156
# 991          R  DLY-TAVG-NORMAL  2010-09-05T00:00:00  GHCND:USW00003103
# 992          R  DLY-TAVG-NORMAL  2010-09-06T00:00:00  GHCND:USC00023009
# 993          S  DLY-TAVG-NORMAL  2010-09-06T00:00:00  GHCND:USC00023160
# 994          Q  DLY-TAVG-NORMAL  2010-09-06T00:00:00  GHCND:USC00029156
# 995          R  DLY-TAVG-NORMAL  2010-09-06T00:00:00  GHCND:USW00003103
# 996          R  DLY-TAVG-NORMAL  2010-09-07T00:00:00  GHCND:USC00023009
# 997          S  DLY-TAVG-NORMAL  2010-09-07T00:00:00  GHCND:USC00023160
# 998          Q  DLY-TAVG-NORMAL  2010-09-07T00:00:00  GHCND:USC00029156
# 999          R  DLY-TAVG-NORMAL  2010-09-07T00:00:00  GHCND:USW00003103
#
#      value   datetime
# 0      264 2010-01-01
# 1      263 2010-01-01
# 2      301 2010-01-01
# 3      292 2010-01-01
# 4      264 2010-01-02
# 5      264 2010-01-02
# 6      302 2010-01-02
# 7      293 2010-01-02
# 8      264 2010-01-03
# 9      264 2010-01-03
# 10     302 2010-01-03
# 11     293 2010-01-03
# 12     265 2010-01-04
# 13     265 2010-01-04
# 14     302 2010-01-04
# 15     294 2010-01-04
# 16     265 2010-01-05
# 17     265 2010-01-05
# 18     303 2010-01-05
# 19     294 2010-01-05
# 20     266 2010-01-06
# 21     266 2010-01-06
# 22     303 2010-01-06
# 23     295 2010-01-06
# 24     266 2010-01-07
# 25     266 2010-01-07
# 26     304 2010-01-07
# 27     295 2010-01-07
# 28     266 2010-01-08
# 29     267 2010-01-08
# ..     ...        ...
# 970    661 2010-08-31
# 971    620 2010-08-31
# 972    593 2010-09-01
# 973    581 2010-09-01
# 974    660 2010-09-01
# 975    618 2010-09-01
# 976    590 2010-09-02
# 977    579 2010-09-02
# 978    658 2010-09-02
# 979    615 2010-09-02
# 980    588 2010-09-03
# 981    577 2010-09-03
# 982    656 2010-09-03
# 983    613 2010-09-03
# 984    586 2010-09-04
# 985    575 2010-09-04
# 986    654 2010-09-04
# 987    611 2010-09-04
# 988    583 2010-09-05
# 989    572 2010-09-05
# 990    652 2010-09-05
# 991    608 2010-09-05
# 992    581 2010-09-06
# 993    570 2010-09-06
# 994    650 2010-09-06
# 995    606 2010-09-06
# 996    578 2010-09-07
# 997    567 2010-09-07
# 998    648 2010-09-07
# 999    603 2010-09-07
#
# [1000 rows x 6 columns]

# %%
# %matplotlib inline
data.plot('datetime', 'value', style='ko-')
